# %%
import matplotlib.pyplot as plt
import torchaudio

# %%
wave_form, sample_rate = torchaudio.load("test.wav")
print(wave_form.shape)
transform = torchaudio.transforms.Spectrogram()
spectrogram = transform(wave_form)
spectrogram = spectrogram.log2()
print(spectrogram.shape)
# Out:
# torch.Size([2, 109368])
# torch.Size([2, 201, 547])

# %%
plt.imshow(spectrogram[0, :, :].numpy())
